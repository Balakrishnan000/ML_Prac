# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4051077e7188c536fc7feb16b656bbd0&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1  19404  Dilwale Dulhania Le Jayenge
# 2    238                The Godfather
# 3    424             Schindler's List
# 4    240       The Godfather: Part II
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23      93.363
# 1  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      20.911
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      68.461
# 3  The true story of how businessman Oskar Schind...   1993-11-30      44.084
# 4  In the continuing saga of the Corleone crime f...   1974-12-20      47.336
#
#    vote_average  vote_count
# 0           8.7       21724
# 1           8.7        3703
# 2           8.7       16185
# 3           8.6       12911
# 4           8.6        9761

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,507):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4051077e7188c536fc7feb16b656bbd0&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\Balakrishnan\AppData\Local\Temp\ipykernel_7056\2220916063.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Balakrishnan\AppData\Local\Temp\ipykernel_7056\2220916063.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Balakrishnan\AppData\Local\Temp\ipykernel_7056\2220916063.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Balakrishnan\AppData\Local\Temp\ipykernel_7056\2220916063.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# theignore_index = true  saves us from wrong indexing 
# 1...20 1...20 1...20 this is how fetch happens tempdf and append would happen
# 1...20 21...40 41 ...60 now idex is ignored and it makes its own in df

# %%
df
# Out:
#           id                                 title  \
# 0        278              The Shawshank Redemption
# 1      19404           Dilwale Dulhania Le Jayenge
# 2        238                         The Godfather
# 3        424                      Schindler's List
# 4        240                The Godfather: Part II
# ...      ...                                   ...
# 10115  12536                          Home Alone 4
# 10116  10285  Jason Goes to Hell: The Final Friday
# 10117  28739           Cabin Fever 2: Spring Fever
# 10118   9823           Mortal Kombat: Annihilation
# 10119  48805            L'allenatore nel pallone 2
#
#                                                 overview release_date  \
# 0      Framed in the 1940s for the double murder of h...   1994-09-23
# 1      Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 2      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
df.shape
# Out:
# (10120, 7)

# %%
df.to_csv('movies.csv')
